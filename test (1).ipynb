# %%
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm
from collections import defaultdict
from random import shuffle
import copy
env_size = 20

# start = np.array([1, 1])
starts = np.array([
    [1, 1], [env_size - 1, env_size - 1], [1, env_size - 1], [env_size - 1, 1],
    [1, env_size / 2], [env_size / 2, 1], [env_size - 1, env_size / 2], [env_size / 2, env_size - 1]
])
goal = np.array([10, 10])
q = defaultdict(lambda: 0)
buffer = set()
actions = np.array([[-1,0],[0,-1],[0,1],[1,0]])
obstacles = np.array([
    [15, 5],
    [5, 8],
    [3, 17],
    [12, 15],
    [7, 3],
    [6., 13],
    [10., 6],
    [8, 14],
    [12, 10]
])

plt.scatter(obstacles[:, 0], obstacles[:, 1])

# %%
def sample_start_on_boundary():
    if np.random.uniform(0, 1) < 0.5:
        x = np.random.choice([1, env_size - 1])
        y = np.random.randint(1, env_size)
    else:
        y = np.random.choice([1, env_size - 1])
        x = np.random.randint(1, env_size)
    return np.array([x, y])

sample_start_on_boundary()
# Out:
# array([14, 19])

# %%
def learn_q():
    listbuffer = list(buffer)
    shuffle(listbuffer)
    for data in listbuffer:
        s, a, s_next, reward, done, _ = data
        if done:
            q[s, a] = q[s, a] + 0.1 * (reward - q[s, a])
        else:
            v_next = max([q[s_next, tuple(a_)] for a_ in actions])
            q[s, a] = q[s, a] + 0.1 * (reward + v_next - q[s, a])

# %%
q = defaultdict(lambda: 0)
buffer = set()
reached = 0
max_iter = 2000
initial_eps = .65
final_eps = 0.05
for num_iter in tqdm(range(max_iter)):
#     state = start.copy()
    state = sample_start_on_boundary()
#     if np.random.rand() < 0.5:
#         selected_start_id = np.random.randint(starts.shape[0])
#         state = starts[selected_start_id].copy()
# #         state = start.copy()
#     else:
#         state = np.random.randint(1, env_size, [2])
#         print (state)
    eps = initial_eps + (final_eps - initial_eps) * num_iter / float(max_iter)
#     print (eps)
    for _ in range(100):
        if np.random.rand() < eps:
            action = actions[np.random.choice(np.arange(len(actions)))]
        else:
            q_values = np.array([q[tuple(state), tuple(a)] for a in actions])
            action = actions[np.random.choice(np.arange(len(actions))[q_values==q_values.max()])]
        state_next = state + action
#         state_next = state_next.clip(0, env_size)
        done = done_goal = (state_next==goal).all()
        reward = np.linalg.norm(state-goal)-np.linalg.norm(state_next-goal)
        min_distance2obstacles = min(np.linalg.norm(obstacles - state_next, axis = 1))
        if 0 in state_next or env_size in state_next or min_distance2obstacles == 0.:
            done = True 
            reward = 0
#             reward = -5.
        
        buffer.add((tuple(state), tuple(action), tuple(state_next), reward, done, done_goal))
        state = state_next
        if done:
            if (state_next==goal).all():
                reached += 1
            break
#     print (state)
    learn_q()

reached
# Out:
# 100%|██████████| 2000/2000 [00:14<00:00, 140.01it/s]
# 1208

# %%
import json

q_str = {}
for k in q:
    q_str[str(k)] = copy.deepcopy(q[k])

# with open("0218_grid_Q.json", "w") as outfile:
#     json.dump(q_str, outfile)
with open("temp.json", "w") as outfile:
    json.dump(q_str, outfile)

# %%
import json 

# with open("0218_grid_Q.json") as infile:
#     q = json.load(infile)
with open("temp.json") as infile:
    q = json.load(infile)

# %%
xs = np.arange(env_size+1)
ys = np.arange(env_size+1)
xx, yy = np.meshgrid(xs, ys)

value = []
for x, y in zip(xx.reshape(-1), yy.reshape(-1)):
    value.append(np.array([q.get(str(((x, y), tuple(a))), 0.) for a in actions]).max())

plt.clf()
plt.cla()
plt.close('all')

value = np.array(value).reshape(xx.shape)
fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(value)

# Loop over data dimensions and create text annotations.
# for i in xs:
#     for j in ys:
#         text = ax.text(j, i, '%.f' % value[i,j], ha="center", va="center", color="w", fontsize=8)

fig.tight_layout()
plt.show()

# %%
import itertools

state_space = list(itertools.product(np.arange(1, env_size, 1),
                                     np.arange(1, env_size, 1)))

def convert_to_V_from_Q(Q):
    V = defaultdict(lambda: 0)
    for state in state_space:
        V[tuple(state)] = max([Q.get(str((tuple(state), tuple(ac))), 0.) for ac in actions])
    return V

# def learn_CLF_from_Q(low_margin = 0.1):
#     # push the landscape based on optimal controls from Q 
#     V = convert_to_V_from_Q()
#     CLF_V = copy.deepcopy(V)
#     for state in state_space:
#         # compute V(s) - max_{a} V(s'| s, a)
#         next_states = copy.deepcopy(state + actions)
#         vals = [V.get(tuple(next_state), 0) for next_state in next_states]
#         best_ac_id = np.argmin(vals) # no need to worry about tie 
#         next_state, next_val = copy.deepcopy(state + actions[best_ac_id]), vals[best_ac_id]
#         val_diff = V.get(tuple(state), 0) - next_val
        
#         if val_diff < low_margin:
#             # want to increase the difference to at least low_margin
#             change = low_margin - val_diff 
#             # need to add change to all V(s' | s, a)
#             # to keep the same control preference at s 
            
#             # also, need to ensure the preference at prior states of s 
        
V = convert_to_V_from_Q(q)
# V

# %%
state_space = np.array(list(itertools.product(np.arange(1, env_size, 1),
                                     np.arange(1, env_size, 1))))

all_relative_states = copy.deepcopy(state_space) - goal 
all_l0_distances = np.sum(np.abs(all_relative_states), axis = 1)
ranks = np.sort(np.unique(all_l0_distances))[::-1]

grouped_states = []
for depth in ranks:
    grouped_states.append(copy.deepcopy(state_space[np.where(all_l0_distances == depth)[0]]))

CLF_V = defaultdict(lambda: 0)
margin = 1.

delta = 0
for group_id in range(len(grouped_states)-1):
    vals_to_add = 0. # for next group_id 
    states = grouped_states[group_id]
    print (delta)
    for state in states:
        CLF_V[tuple(state)] = V[tuple(state)] 
        if group_id != 0:
            CLF_V[tuple(state)] += delta 
    delta = 0
            
    next_group_states = grouped_states[group_id + 1]
    for state in states:
        next_states = copy.deepcopy(state + actions)
        next_states_in_next_group = []
        for next_state in next_states:
            if (np.all(next_group_states == next_state, axis = 1)).any(): 
                next_states_in_next_group.append(next_state)
        values = [V[tuple(s)] for s in next_states_in_next_group]
        val_diff = max(values) - CLF_V[tuple(state)]
        if val_diff < margin:
            delta = max(delta, margin - val_diff)
            
group_id = len(grouped_states) - 1 
states = grouped_states[group_id]
print (delta)
for state in states:
    CLF_V[tuple(state)] = V[tuple(state)] 
    if group_id != 0:
        CLF_V[tuple(state)] += delta
# Out:
# 0
# 1.6863274825655523
# 3.3261678103664636
# 5.009730496616566
# 6.639876309351209
# 8.319826788669978
# 9.937045978920231
# 11.61207767725214
# 13.463232874622706
# 15.131176449055332
# 17.131176449055324
# 19.13117644905532
# 21.131176449055317
# 23.131176449055314
# 29.131176449055296
# 31.131176449055296
# 35.13117644905529
# 37.13117644905529
# 39.13117644905529

# %%
for group_id in range(len(grouped_states)):
    print ("group id: {}".format(group_id))
    states = grouped_states[group_id]
    for state in states:
        print ("\t {}, {}".format(state, CLF_V[tuple(state)]))
    print ("")
# Out:
# group id: 0
# 	 [1 1], 12.727922061357773
# 	 [ 1 19], 12.72792206135777
# 	 [19  1], 12.72792206135777
# 	 [19 19], 12.727922061357773
#
# group id: 1
# 	 [1 2], 13.727922061357773
# 	 [ 1 18], 13.72792206135777
# 	 [2 1], 13.727922061357773
# 	 [ 2 19], 13.72792206135777
# 	 [18  1], 13.72792206135777
# 	 [18 19], 13.727922061357773
# 	 [19  2], 13.72792206135777
# 	 [19 18], 13.727922061357773
#
# group id: 2
# 	 [1 3], 14.727922061357777
# 	 [ 1 17], 14.727922061357773
# 	 [2 2], 14.639876309351159
# 	 [ 2 18], 14.639876309351155
# 	 [3 1], 14.727922061357777
# 	 [ 3 19], 14.727922061357773
# 	 [17  1], 14.727922061357773
# 	 [17 19], 14.727922061357773
# 	 [18  2], 14.639876309351155
# 	 [18 18], 14.639876309351159
# 	 [19  3], 14.727922061357773
# 	 [19 17], 14.727922061357777
#
# group id: 3
# 	 [1 4], 15.826384323008476
# 	 [ 1 16], 15.826384323008472
# 	 [2 3], 15.639876309351159
# 	 [ 2 17], 15.639876309351155
# 	 [3 2], 15.639876309351159
# 	 [ 3 18], 15.639876309351155
# 	 [4 1], 15.826384323008476
# 	 [ 4 19], 15.826384323008472
# 	 [16  1], 15.826384323008472
# 	 [16 19], 15.826384323008472
# 	 [17  2], 15.639876309351155
# 	 [17 18], 15.639876309351155
# 	 [18  3], 15.639876309351155
# 	 [18 17], 15.639876309351159
# 	 [19  4], 15.826384323008472
# 	 [19 16], 15.826384323008476
#
# group id: 4
# 	 [1 5], 16.935506450338156
# 	 [ 1 15], 16.935506450338153
# 	 [2 4], 16.63987630935116
# 	 [ 2 16], 16.639876309351155
# 	 [3 3], 16.539371245962823
# 	 [ 3 17], 6.639876309351209
# 	 [4 2], 16.63987630935116
# 	 [ 4 18], 16.639876309351155
# 	 [5 1], 16.935506450338156
# 	 [ 5 19], 16.935506450338153
# 	 [15  1], 16.935506450338156
# 	 [15 19], 16.935506450338156
# 	 [16  2], 16.639876309351155
# 	 [16 18], 16.639876309351155
# 	 [17  3], 16.53937124596282
# 	 [17 17], 16.539371245962823
# 	 [18  4], 16.639876309351155
# 	 [18 16], 16.63987630935116
# 	 [19  5], 16.935506450338156
# 	 [19 15], 16.935506450338156
#
# group id: 5
# 	 [1 6], 18.168684590466036
# 	 [ 1 14], 18.168684590466032
# 	 [2 5], 17.753807920726537
# 	 [ 2 15], 17.753807920726533
# 	 [3 4], 17.539371245962823
# 	 [ 3 16], 17.53937124596282
# 	 [4 3], 17.539371245962823
# 	 [ 4 17], 17.53937124596282
# 	 [5 2], 17.753807920726537
# 	 [14  9], 27.254282074672965
# 	 [14 11], 27.254282074672965
# 	 [15 10], 28.1311764490553
#
# group id: 14
# 	 [ 6 10], 33.13117644905529
# 	 [7 9], 32.29345410922367
# 	 [ 7 11], 32.29345410922367
# 	 [8 8], 31.95960357380148
# 	 [ 8 12], 31.95960357380148
# 	 [9 7], 32.29345410922367
# 	 [ 9 13], 32.29345410922367
# 	 [10  6], 29.131176449055296
# 	 [10 14], 33.13117644905529
# 	 [11  7], 32.29345410922367
# 	 [11 13], 32.29345410922367
# 	 [12  8], 31.95960357380148
# 	 [12 12], 31.95960357380148
# 	 [13  9], 32.29345410922367
# 	 [13 11], 32.29345410922367
# 	 [14 10], 33.13117644905529
#
# group id: 15
# 	 [ 7 10], 34.13117644905529
# 	 [8 9], 33.36724442655508
# 	 [ 8 11], 33.36724442655508
# 	 [9 8], 33.36724442655508
# 	 [ 9 12], 33.36724442655508
# 	 [10  7], 34.13117644905529
# 	 [10 13], 34.13117644905529
# 	 [11  8], 33.36724442655508
# 	 [11 12], 33.36724442655508
# 	 [12  9], 33.36724442655508
# 	 [12 11], 33.36724442655508
# 	 [13 10], 34.13117644905529
#
# group id: 16
# 	 [ 8 10], 37.13117644905529
# 	 [9 9], 36.54539001142838
# 	 [ 9 11], 36.54539001142838
# 	 [10  8], 37.13117644905529
# 	 [10 12], 37.13117644905529
# 	 [11  9], 36.54539001142838
# 	 [11 11], 36.54539001142838
# 	 [12 10], 35.13117644905529
#
# group id: 17
# 	 [ 9 10], 38.13117644905529
# 	 [10  9], 38.13117644905529
# 	 [10 11], 38.13117644905529
# 	 [11 10], 38.13117644905529
#
# group id: 18
# 	 [10 10], 39.13117644905529

# %%
xs = np.arange(env_size+1)
ys = np.arange(env_size+1)
xx, yy = np.meshgrid(xs, ys)

value = []
for x, y in zip(xx.reshape(-1), yy.reshape(-1)):
    value.append(CLF_V[tuple([x, y])])

plt.clf()
plt.cla()
plt.close('all')

value = np.array(value).reshape(xx.shape)
fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(value)

# Loop over data dimensions and create text annotations.
# for i in xs:
#     for j in ys:
#         text = ax.text(j, i, '%.f' % value[i,j], ha="center", va="center", color="w", fontsize=8)

fig.tight_layout()
plt.show()

# %%
# q = defaultdict(lambda: 0)
# depth_CLF = defaultdict(lambda: 0)

# buffer = set()
# reached = 0
# max_iter = 2000
# initial_eps = .65
# final_eps = 0.05

# env_size = 20 
# goal = np.array([10, 10])
# for num_iter in tqdm(range(max_iter)):
# #     state = start.copy()
#     state = sample_start_on_boundary()
# #     if np.random.rand() < 0.5:
# #         selected_start_id = np.random.randint(starts.shape[0])
# #         state = starts[selected_start_id].copy()
# # #         state = start.copy()
# #     else:
# #         state = np.random.randint(1, env_size, [2])
# #         print (state)
#     eps = initial_eps + (final_eps - initial_eps) * num_iter / float(max_iter)
# #     print (eps)
#     just_start = True
#     for _ in range(100):
#         if np.random.rand() < eps:
#             action = actions[np.random.choice(np.arange(len(actions)))]
#         else:
#             q_values = np.array([q[tuple(state), tuple(a)] for a in actions])
#             action = actions[np.random.choice(np.arange(len(actions))[q_values==q_values.max()])]
#         state_next = state + action
# #         state_next = state_next.clip(0, env_size)
#         done = (state_next==goal).all()
#         reward = np.linalg.norm(state-goal)-np.        s, a, s_next, reward, done, done_goaled = data
linalg.norm(state_next-goal)
#         min_distance2obstacles = min(np.linalg.norm(obstacles - state_next, axis = 1))
#         if 0 in state_next or env_size in state_next or min_distance2obstacles == 0.:
#             done = True 
#             reward = 0
# #             reward = -5.
        
#         buffer.add((tuple(state), tuple(action), tuple(state_next), reward, done, just_start))
#         just_start = False
#         state = state_next
#         if done:
#             if (state_next==goal).all():
#                 reached += 1
#             break
# #     print (state)
#     learn_q()
#     learn_CLF_from_buffer()

# reached
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-8b7201ddd79f> in <module>
#      33 #         done = (state_next==goal).all()
#      34 #         reward = np.linalg.norm(state-goal)-np.        s, a, s_next, reward, done, done_goaled = data
# ---> 35 linalg.norm(state_next-goal)
#      36 #         min_distance2obstacles = min(np.linalg.norm(obstacles - state_next, axis = 1))
#      37 #         if 0 in state_next or env_size in state_next or min_distance2obstacles == 0.:
#
# NameError: name 'linalg' is not defined

# %%
def compute_depth_from_history(transitions_history,  # key: next state, value: potential prior states
                               transitions_history2, # key: state, value: potential next states
                               goals,
                               verbose = False):

    depth_CLF = defaultdict(lambda: 0)

    explored = []
    to_explore_next = []
    for goal in goals:
        depth_CLF[tuple(goal)] = 10 
        explored.append(tuple(goal))
        to_explore_next += transitions_history[tuple(goal)]

    while len(to_explore_next) != 0:
        temp_to_explore = []
        for state in to_explore_next:
            next_state_depth =  float('inf')
            for next_state in transitions_history2[state]:
                if next_state in explored:
                    next_state_depth = min(next_state_depth, depth_CLF[next_state])
            assert next_state_depth != float('inf')
            depth_CLF[state] = next_state_depth - 1 
            if verbose:
                print ("found {}: {}".format(state, depth_CLF[state]))
            explored.append(state)
            for prior_state in transitions_history[state]:
                if prior_state not in explored and prior_state not in to_explore_next and prior_state not in temp_to_explore:
                    temp_to_explore.append(prior_state)
        to_explore_next = temp_to_explore
        if verbose:
            print ("to_explore_next: ", to_explore_next)
            print ("--------------------------------\n")
#     print (depth_CLF)
    min_val = min(depth_CLF.values())
    for k in depth_CLF:
        depth_CLF[k] -= min_val 
    return depth_CLF

# %%
# V_CLF = defaultdict(lambda: 0)
# delta_CLF = defaultdict(lambda: 0)

# delta = 0
# for group_id in range(len(grouped_states)-1):
#     vals_to_add = 0. # for next group_id 
#     states = grouped_states[group_id]
#     print (delta)
#     for state in states:
#         CLF_V[tuple(state)] = V[tuple(state)] 
#         if group_id != 0:
#             CLF_V[tuple(state)] += delta 
#     delta = 0
            
#     next_group_states = grouped_states[group_id + 1]
#     for state in states:
#         next_states = copy.deepcopy(state + actions)
#         next_states_in_next_group = []
#         for next_state in next_states:
#             if (np.all(next_group_states == next_state, axis = 1)).any(): 
#                 next_states_in_next_group.append(next_state)
#         values = [V[tuple(s)] for s in next_states_in_next_group]
#         val_diff = max(values) - CLF_V[tuple(state)]
#         if val_diff < margin:
#             delta = max(delta, margin - val_diff)
            
# group_id = len(grouped_states) - 1 
# states = grouped_states[group_id]
# print (delta)
# for state in states:
#     CLF_V[tuple(state)] = V[tuple(state)] 
#     if group_id != 0:
#         CLF_V[tuple(state)] += delta 
        
def learn_CLF_from_buffer(goals_from_buffer,
                          margin = 0.1,
                          num_best = 2):
    listbuffer = list(buffer)
    shuffle(listbuffer)
    all_states = []
    for data in listbuffer:
        s, a, s_next, reward, done, done_goaled = data
        all_states.append(s_next)
        
        # update history of transitions 
        if s not in transitions_history[s_next]:
            transitions_history[s_next].append(s)
        if s_next not in transitions_history2[s]:
            transitions_history2[s].append(s_next)
            
        if done_goaled and s_next not in goals_from_buffer:
            goals_from_buffer.append(s_next)
            
        if done:
            q_CLF[s, a] = q_CLF[s, a] + 0.1 * (reward - q_CLF[s, a])
        else:
            v_next = max([q_CLF[s_next, tuple(a_)] for a_ in actions])
            q_CLF[s, a] = q_CLF[s, a] + 0.1 * (reward + v_next - q_CLF[s, a])
    
    # using goal info directly to spot the states close to the goal,
    # if goal is never reached in buffer
    goal_not_reached = False
    if len(goals_from_buffer) == 0: 
        distances2goal = np.linalg.norm(all_states - goal, axis = 1)
        picked_indices = np.argsort(distances2goal)[:num_best]
#         print (picked_indices)
        all_states = np.array(all_states)
        goals_from_buffer = all_states[picked_indices]
        goal_not_reached = True
    depth_CLF = compute_depth_from_history(transitions_history,
                                           transitions_history2,
                                           goals_from_buffer)
    max_depth = max(depth_CLF.values())
    
    V_CLF = convert_to_V_from_Q(q_CLF)
    delta_CLF = defaultdict(lambda: 0)
    # compute deltas for the current learned V & depth
    for data in listbuffer:
        s, a, s_next, reward, done, done_goaled = data
        
        depth, depth_next = depth_CLF[s], depth_CLF[s_next]
        val, val_next = V_CLF[s] + delta_CLF[depth], V_CLF[s_next] + delta_CLF[depth_next]
        if depth_next >= depth:
            val_diff = val_next - val 
            if val_diff < margin:
                delta_CLF[depth_next] = max(delta_CLF[depth_next], margin - val_diff)
                
    if goal_not_reached:
        goals_from_buffer = []
    return V_CLF, delta_CLF, goals_from_buffer, depth_CLF
            
#             depth_CLF[s_next] = min(depth_CLF[s_next], depth_CLF[s] + 1) 
        
#         if done:
#             q[s, a] = q[s, a] + 0.1 * (reward - q[s, a])
#         else:
#             v_next = max([q[s_next, tuple(a_)] for a_ in actions])
#             q[s, a] = q[s, a] + 0.1 * (reward + v_next - q[s, a])

# %%
goals_from_buffer = []
V_CLF, delta_CLF = learn_CLF_from_buffer(goals_from_buffer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-bf6a4b845082> in <module>
#       1 goals_from_buffer = []
# ----> 2 V_CLF, delta_CLF = learn_CLF_from_buffer(goals_from_buffer)
#
# ValueError: too many values to unpack (expected 2)

# %%
q_CLF = defaultdict(lambda: 0)
V_CLF = defaultdict(lambda: 0)
delta_CLF = defaultdict(lambda: 0)
depth_CLF = defaultdict(lambda: 0)

goals_from_buffer = []
transitions_history = defaultdict(list)
transitions_history2 = defaultdict(list)

buffer = set()
reached = 0
max_iter = 2000
initial_eps = .65
final_eps = 0.05
for num_iter in tqdm(range(max_iter)):
    state = sample_start_on_boundary()
    eps = initial_eps + (final_eps - initial_eps) * num_iter / float(max_iter)
#     print (eps)
    for _ in range(100):
        if np.random.rand() < eps:
            action = actions[np.random.choice(np.arange(len(actions)))]
        else:
            next_states = copy.deepcopy(state + actions)
            vals = np.array([V_CLF[tuple(next_state)] + delta_CLF[depth_CLF[tuple(next_state)]] for next_state in next_states])
            action = actions[np.random.choice(np.arange(len(actions))[vals==vals.max()])]
            
        state_next = state + action
        done_goaled = (state_next==goal).all()
        reward = np.linalg.norm(state-goal) - np.linalg.norm(state_next-goal)
        
        min_distance2obstacles = min(np.linalg.norm(obstacles - state_next, axis = 1))
        done_failed = 0 in state_next or env_size in state_next or min_distance2obstacles == 0.
        done = done_goaled or done_failed
        
        buffer.add((tuple(state), tuple(action), tuple(state_next), reward, done, done_goaled))
        state = state_next
        if done:
            if (state_next==goal).all():
                reached += 1
            break
    V_CLF, delta_CLF, goals_from_buffer, depth_CLF = learn_CLF_from_buffer(goals_from_buffer)

reached
# Out:
# 100%|██████████| 2000/2000 [00:47<00:00, 41.79it/s]
# 49

# %%
# def verify_CLF(values,
#                goal_state,
#                min_margin = 0.1):
#     for state in state_space:
#         next_states = copy.deepcopy(state + actions)
#         best_next_val = min([values[tuple(next_state)] for next_state in next_states])
#         diff = values[tuple(state)] - best_next_val
#         if (state != goal_state).all() and diff <= min_margin:
#             print ("invalid!!! ", state, values[tuple(state)], next_states, best_next_val)
#     all_vals = list(values.values()) 
#     goal_val = values[tuple(goal_state)]
#     if min(all_vals) != goal_val:
#         print ("goal not the lowest")
        
# verify_CLF(V, goal)

# %%
use_V = True

x = np.array([19, 1])#copy.deepcopy(start)
for _ in range(500):
    next_states = copy.deepcopy(x + actions)
    temp = [CLF_V[tuple(next_state)] for next_state in next_states]
#         print (next_states, temp)

#     print (temp)
#     print (max(temp))
    ac_id = np.argmax([q[str((tuple(x), tuple(actions[i])))] for i in range(len(actions))])
    action = copy.deepcopy(actions[ac_id]) 
#     x = (x + action).clip(1, env_size - 1) 
    x += action 
    min_distance2obstacles = min(np.linalg.norm(obstacles - x, axis = 1))
    if 0 in x or env_size in x or min_distance2obstacles == 0.:
        break
#     print (x)
    if x[0] == goal[0] and x[1] == goal[1]:
        break
x
# Out:
# array([10, 10])

# %%
CLF_V
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {(1, 1): 12.727922061357773,
#              (1, 19): 12.72792206135777,
#              (19, 1): 12.72792206135777,
#              (19, 19): 12.727922061357773,
#              (1, 2): 13.727922061357773,
#              (1, 18): 13.72792206135777,
#              (2, 1): 13.727922061357773,
#              (2, 19): 13.72792206135777,
#              (18, 1): 13.72792206135777,
#              (18, 19): 13.727922061357773,
#              (19, 2): 13.72792206135777,
#              (19, 18): 13.727922061357773,
#              (1, 3): 14.727922061357777,
#              (1, 17): 14.727922061357773,
#              (2, 2): 14.639876309351159,
#              (2, 18): 14.639876309351155,
#              (3, 1): 14.727922061357777,
#              (3, 19): 14.727922061357773,
#              (17, 1): 14.727922061357773,
#              (17, 19): 14.727922061357773,
#              (18, 2): 14.639876309351155,
#              (18, 18): 14.639876309351159,
#              (19, 3): 14.727922061357773,
#              (8, 0): 0,
#              (9, 0): 0,
#              (10, 0): 0,
#              (11, 0): 0,
#              (12, 0): 0,
#              (13, 0): 0,
#              (14, 0): 0,
#              (15, 0): 0,
#              (16, 0): 0,
#              (17, 0): 0,
#              (18, 0): 0,
#              (19, 0): 0,
#              (20, 0): 0,
#              (0, 1): 0,
#              (20, 1): 0,
#              (0, 2): 0,
#              (20, 2): 0,
#              (0, 3): 0,
#              (20, 3): 0,
#              (0, 4): 0,
#              (20, 4): 0,
#              (0, 5): 0,
#              (20, 5): 0,
#              (0, 6): 0,
#              (20, 6): 0,
#              (0, 7): 0,
#              (20, 7): 0,
#              (0, 8): 0,
#              (20, 8): 0,
#              (0, 9): 0,
#              (20, 9): 0,
#              (0, 10): 0,
#              (20, 10): 0,
#              (0, 11): 0,
#              (20, 11): 0,
#              (0, 12): 0,
#              (20, 12): 0,
#              (0, 13): 0,
#              (20, 13): 0,
#              (0, 14): 0,
#              (20, 14): 0,
#              (0, 15): 0,
#              (20, 15): 0,
#              (0, 16): 0,
#              (20, 16): 0,
#              (0, 17): 0,
#              (20, 17): 0,
#              (0, 18): 0,
#              (20, 18): 0,
#              (0, 19): 0,
#              (20, 19): 0,
#              (0, 20): 0,
#              (1, 20): 0,
#              (2, 20): 0,
#              (3, 20): 0,
#              (4, 20): 0,
#              (5, 20): 0,
#              (6, 20): 0,
#              (7, 20): 0,
#              (8, 20): 0,
#              (9, 20): 0,
#              (10, 20): 0,
#              (11, 20): 0,
#              (12, 20): 0,
#              (13, 20): 0,
#              (14, 20): 0,
#              (15, 20): 0,
#              (16, 20): 0,
#              (17, 20): 0,
#              (18, 20): 0,
#              (19, 20): 0,
#              (20, 20): 0})

# %%
import itertools
state_space = list(itertools.product(np.arange(1, env_size, 1),
                                     np.arange(1, env_size, 1)))

s = state_space[0]
q[str((tuple(s), tuple(actions[0])))]
# Out:
# 0.0

# %%
from CLF import *

import itertools

# %%
# learn CLF from well-trained Q.
# for now, we construct the entire opt/nopt sets 

state_space = list(itertools.product(np.arange(1, env_size, 1),
                                     np.arange(1, env_size, 1)))

opt_states, opt_nstates, opt_acs, nopt_states, nopt_nstates, nopt_acs = [], [], [], [], [], []
all_q_vals, all_rewards = {}, {}
all_states = {}
# all_states, all_nstates, all_acs = [], [], []

for state in state_space:
    q_vals = [q.get(str((tuple(state), tuple(actions[i]))), 0.) for i in range(len(actions))]
    if sum(q_vals) == 0: # ignore the unvisited states
        continue
    q_vals = np.array(q_vals)
#     print (q_vals)
    best_ac_ids = np.where(q_vals == max(q_vals))[0]
#     print (best_ac_ids)
    processed_state = convert_polar_coordinates([state])[0]
    all_states[tuple(processed_state)] = []
    all_q_vals[tuple(processed_state)] = []
    all_rewards[tuple(processed_state)] = []
    
    for ac_id in range(len(actions)):
        ac = actions[ac_id]
        state_next = state + ac
#         state_next = state_next.clip(1, env_size - 1)
        if ac_id in best_ac_ids:
#             if state_next[0] < state[0] or state_next[1] < state[1]:
#                 continue
            opt_states.append(copy.deepcopy(state))
            opt_nstates.append(copy.deepcopy(state_next))   
            opt_acs.append(copy.deepcopy(ac))
        else:
            nopt_states.append(copy.deepcopy(state))
            nopt_nstates.append(copy.deepcopy(state_next)) 
            nopt_acs.append(copy.deepcopy(ac))
            
#         all_states.append(copy.deepcopy(state))
        all_states[tuple(processed_state)].append(copy.deepcopy(convert_polar_coordinates([state_next])[0])) 
        all_q_vals[tuple(processed_state)].append(copy.deepcopy(q.get(str((tuple(state), tuple(ac))), 0.))) 
        reward = np.linalg.norm(state - goal) - np.linalg.norm(state_next - goal)
        all_rewards[tuple(processed_state)].append(copy.deepcopy(reward))

goal_copied = copy.deepcopy(goal)
data = [convert_polar_coordinates(np.array(opt_states)), convert_polar_coordinates(np.array(opt_nstates)), convert_polar_coordinates(np.array(nopt_states)), convert_polar_coordinates(np.array(nopt_nstates))]
# data = [np.array(opt_states), np.array(opt_nstates), np.array(all_nstates), np.array(all_q_vals), np.array(all_rewards)]
# processed_all_states = {k:convert_polar_coordinates(all_states[k]) for k in all_states}

data = [convert_polar_coordinates(np.array(opt_states)), 
        convert_polar_coordinates(np.array(opt_nstates)), 
        all_states, all_q_vals, all_rewards]
# _ = [print(d.shape) for d in data]
len(all_states)
# Out:
# 360

# %%
data[0][:5], data[1][:5]
# Out:
# (array([[12.72792206,  3.92699082],
#         [12.72792206,  3.92699082],
#         [12.04159458,  3.86823499],
#         [12.04159458,  3.86823499],
#         [11.40175425,  3.80263582]]),
#  array([[12.04159458,  3.86823499],
#         [12.04159458,  3.98574664],
#         [11.40175425,  3.80263582],
#         [11.3137085 ,  3.92699082],
#         [10.81665383,  3.72959526]]))

# %%
def convert_polar_coordinates(positions):
    temp = positions - goal
    distances = np.linalg.norm(positions - goal, axis = 1)
    ang = np.arctan2(temp[:, 1], temp[:, 0]) #/ np.pi 
    ang[np.where(ang < 0)] += 2. * np.pi
    return np.hstack([distances.reshape([-1, 1]), ang.reshape([-1, 1])])

temp = convert_polar_coordinates(opt_states)
temp
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-f3eec69bac17> in <module>
#       6     return np.hstack([distances.reshape([-1, 1]), ang.reshape([-1, 1])])
#       7
# ----> 8 temp = convert_polar_coordinates(opt_states)
#       9 temp
#
# <ipython-input-11-f3eec69bac17> in convert_polar_coordinates(positions)
#       1 def convert_polar_coordinates(positions):
# ----> 2     temp = positions - goal
#       3     distances = np.linalg.norm(positions - goal, axis = 1)
#       4     ang = np.arctan2(temp[:, 1], temp[:, 0]) #/ np.pi
#       5     ang[np.where(ang < 0)] += 2. * np.pi
#
# ValueError: operands could not be broadcast together with shapes (0,) (2,)

# %%
i = -23

data[0][i], data[1][i]
# Out:
# (array([49, 34]), array([48, 34]))

# %%
margin = 0.1
num_iters = 2000
verbose_iter = 50
lr = 1e-4

from CLF import *

model = NCLF(2, [64, 64])
model.compile(Adam(lr = lr))
model.fit(data, 
          train_w_properties = False,
          margin = margin,
          num_iters = num_iters,
          verbose_iter = verbose_iter)
# Out:
# iter 0: (1.6428702, 0.31250134, 1.3303689)
# iter 50: (1.48414, 0.028323723, 1.4558163)
# iter 100: (1.5045608, 0.014263217, 1.4902976)
# iter 150: (1.5099689, 0.012709077, 1.4972599)
# iter 200: (1.5163834, 0.012572769, 1.5038106)
# iter 250: (1.5231669, 0.012458873, 1.510708)
# iter 300: (1.5305334, 0.012344999, 1.5181885)
# iter 350: (1.5384904, 0.012227198, 1.5262632)
# iter 400: (1.5473439, 0.01209859, 1.5352453)
# iter 450: (1.5571249, 0.01195808, 1.5451667)
# iter 500: (1.567883, 0.011806922, 1.556076)
# iter 550: (1.579229, 0.011659524, 1.5675695)
# iter 600: (1.5880837, 0.011581253, 1.5765024)
# iter 650: (1.5966172, 0.011512984, 1.5851042)
# iter 700: (1.6036032, 0.011471042, 1.5921322)
# iter 750: (1.6101218, 0.01143643, 1.5986854)
# iter 800: (1.616916, 0.01140247, 1.6055135)
# iter 850: (1.6232017, 0.011375645, 1.6118261)
# iter 900: (1.628855, 0.011354808, 1.6175002)
# iter 950: (1.6347545, 0.011333308, 1.6234212)
# iter 1000: (1.6409824, 0.011310789, 1.6296716)
# iter 1050: (1.6475543, 0.011287227, 1.6362671)
# iter 1100: (1.6544861, 0.011262604, 1.6432234)
# iter 1150: (1.6616305, 0.011238028, 1.6503925)
# iter 1200: (1.6680275, 0.011220438, 1.6568071)
# iter 1250: (1.6746857, 0.011201374, 1.6634843)
# iter 1300: (1.6816841, 0.011182533, 1.6705016)
# iter 1350: (1.6890352, 0.011160349, 1.6778748)
# iter 1400: (1.6950667, 0.011150444, 1.6839162)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-b7f0cb542732> in <module>
#      12           margin = margin,
#      13           num_iters = num_iters,
# ---> 14           verbose_iter = verbose_iter)
#
# ~/Documents/NCLF/CLF.py in fit(self, data, train_w_properties, margin, goal_value, init_value, num_iters, verbose_iter)
#      30         for i in range(num_iters):
#      31             if not train_w_properties:
# ---> 32                 loss = self._train_step(data, margin, goal_value, init_value)
#      33             else:
#      34                 loss = self._train_step2(data, margin)
#
# ~/Documents/NCLF/CLF.py in _train_step(self, data, margin, goal_value, init_value)
#      56             rs = np.vstack([all_rewards[k] for k in all_rewards])
#      57 #             print (all_vals)
# ---> 58             all_vals = tf.reshape(all_vals, qs.shape) #all_vals.reshape(qs.shape)
#      59             all_nvals = tf.reshape(all_nvals, qs.shape) #all_nvals.reshape(qs.shape)
#      60             temp = qs + goal_value - rs - all_vals
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1080       # Fallback dispatch system (dispatch v1):
#    1081       try:
# -> 1082         return dispatch_target(*args, **kwargs)
#    1083       except (TypeError, ValueError):
#    1084         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in reshape(tensor, shape, name)
#     192     A `Tensor`. Has the same type as `tensor`.
#     193   """
# --> 194   result = gen_array_ops.reshape(tensor, shape, name)
#     195   tensor_util.maybe_set_static_shape(result, shape)
#     196   return result
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py in reshape(tensor, shape, name)
#    8540     try:
#    8541       return reshape_eager_fallback(
# -> 8542           tensor, shape, name=name, ctx=_ctx)
#    8543     except _core._SymbolicException:
#    8544       pass  # Add nodes to the TensorFlow graph.
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py in reshape_eager_fallback(tensor, shape, name, ctx)
#    8561 def reshape_eager_fallback(tensor, shape, name, ctx):
#    8562   _attr_T, (tensor,) = _execute.args_to_matching_eager([tensor], ctx, [])
# -> 8563   _attr_Tshape, (shape,) = _execute.args_to_matching_eager([shape], ctx, [_dtypes.int32, _dtypes.int64, ], _dtypes.int32)
#    8564   _inputs_flat = [tensor, shape]
#    8565   _attrs = ("T", _attr_T, "Tshape", _attr_Tshape)
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in args_to_matching_eager(l, ctx, allowed_dtypes, default_dtype)
#     254       # not list allowed dtypes, in which case we should skip this.
#     255       if dtype is None and allowed_dtypes:
# --> 256         tensor = ops.convert_to_tensor(t, ctx=ctx)
#     257         # If we did not match an allowed dtype, try again with the default
#     258         # dtype. This could be because we have an empty tensor and thus we
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     181         with Trace(trace_name, **trace_kwargs):
#     182           return func(*args, **kwargs)
# --> 183       return func(*args, **kwargs)
#     184
#     185     return wrapped
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1693
#    1694     if ret is None:
# -> 1695       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1696
#    1697     if ret is NotImplemented:
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1534 def _autopacking_conversion_function(v, dtype=None, name=None, as_ref=False):
#    1535   """Tensor conversion function that automatically packs arguments."""
# -> 1536   if as_ref or _should_not_autopack(v):
#    1537     return NotImplemented
#    1538   inferred_dtype = _get_dtype_from_nested_lists(v)
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/ops/array_ops.py in _should_not_autopack(v)
#    1528   # pylint: disable=unidiomatic-typecheck
#    1529   # TODO(slebedev): add nest.all?
# -> 1530   return all(type(elem) in _NON_AUTOPACKABLE_TYPES for elem in nest.flatten(v))
#    1531   # pylint: enable=unidiomatic-typecheck
#    1532
#
# ~/anaconda3/envs/NCLF/lib/python3.7/site-packages/tensorflow/python/util/nest.py in flatten(structure, expand_composites)
#     449     return [None]
#     450   expand_composites = bool(expand_composites)
# --> 451   return _pywrap_utils.Flatten(structure, expand_composites)
#     452
#     453
#
# KeyboardInterrupt:

# %%
model.model.save_weights("./0215_NCLF_model_3")
# # model.model.load_weights("./0212_NCLF_model")

# %%
data[0][:10], data[1][:10]
# Out:
# (array([[-24, -24],
#         [-24, -24],
#         [-24, -23],
#         [-24, -22],
#         [-24, -22],
#         [-24, -21],
#         [-24, -21],
#         [-24, -20],
#         [-24, -20],
#         [-24, -19]]),
#  array([[-24, -23],
#         [-23, -24],
#         [-23, -23],
#         [-24, -21],
#         [-23, -22],
#         [-24, -20],
#         [-23, -21],
#         [-24, -19],
#         [-23, -20],
#         [-23, -19]]))

# %%
x = [29, 26]

q_vals = [q.get(str((tuple(x), tuple(actions[i]))), 0) for i in range(len(actions))]
q_vals = np.array(q_vals)
best_ac_ids = np.where(q_vals == max(q_vals))[0]
    
for ac in actions:
    print (ac, q.get(str((tuple(x), tuple(ac))), 0))
best_ac_ids
# Out:
# [-1  0] 4.123105625617651
# [ 0 -1] 4.123105625617651
# [0 1] 4.1231056256176455
# [1 0] 4.123105625617644
# array([0, 1])

# %%
opt_vals = model.predict(convert_polar_coordinates(np.array(opt_states)).astype(np.float))
opt_nvals = model.predict(convert_polar_coordinates(np.array(opt_nstates)).astype(np.float))

num_violations = 0
for i in range(len(opt_vals)):
    val, nval = opt_vals[i], opt_nvals[i]
    if nval - val < margin:
        print ("opt_state: ", data[0][i])
        print ("opt_nstate: ", data[1][i])
        print (val, nval, nval - val, margin)
        print ("")
        num_violations += 1
# Out:
# opt_state:  [9.05538514 3.25224987]
# opt_nstate:  [9.         3.14159265]
# [-5.6341558] [-5.5989532] [0.0352025] 0.1
#
# opt_state:  [9.05538514 3.03093543]
# opt_nstate:  [9.         3.14159265]
# [-5.6323447] [-5.5989532] [0.03339148] 0.1
#
# opt_state:  [8.06225775 3.26594765]
# opt_nstate:  [8.         3.14159265]
# [-5.0192723] [-4.979703] [0.03956938] 0.1
#
# opt_state:  [8.06225775 3.01723766]
# opt_nstate:  [8.         3.14159265]
# [-5.0172386] [-4.979703] [0.03753567] 0.1
#
# opt_state:  [7.07106781 3.28348971]
# opt_nstate:  [7.         3.14159265]
# [-4.4056225] [-4.3604517] [0.04517078] 0.1
#
# opt_state:  [7.07106781 2.9996956 ]
# opt_nstate:  [7.         3.14159265]
# [-4.4033003] [-4.3604517] [0.04284859] 0.1
#
# opt_state:  [6.08276253 3.30674133]
# opt_nstate:  [6.         3.14159265]
# [-3.793804] [-3.7412019] [0.05260205] 0.1
#
# opt_state:  [6.08276253 2.97644398]
# opt_nstate:  [6.         3.14159265]
# [-3.7911022] [-3.7412019] [0.04990029] 0.1
#
# opt_state:  [5.09901951 3.33898821]
# opt_nstate:  [5.         3.14159265]
# [-3.1848845] [-3.1219516] [0.06293297] 0.1
#
# opt_state:  [5.09901951 2.94419709]
# opt_nstate:  [5.         3.14159265]
# [-3.1816545] [-3.1219516] [0.05970287] 0.1
#
# opt_state:  [4.12310563 3.38657132]
# opt_nstate:  [4.         3.14159265]
# [-2.5809379] [-2.5027015] [0.07823634] 0.1
#
# opt_state:  [4.12310563 2.89661399]
# opt_nstate:  [4.         3.14159265]
# [-2.5769305] [-2.5027015] [0.074229] 0.1
#
# opt_state:  [3.16227766 2.8198421 ]
# opt_nstate:  [3.         3.14159265]
# [-1.9813094] [-1.883451] [0.09785843] 0.1
#
# opt_state:  [5.38516481 1.9513027 ]
# opt_nstate:  [5.83095189 2.11121583]
# [-3.3507276] [-3.6280894] [-0.27736187] 0.1
#
# opt_state:  [5.38516481 1.9513027 ]
# opt_nstate:  [6.32455532 1.89254688]
# [-3.3507276] [-3.9319649] [-0.5812373] 0.1
#
# opt_state:  [9.05538514 4.60173176]
# opt_nstate:  [9.         4.71238898]
# [-5.645195] [-5.6118035] [0.03339148] 0.1
#
# opt_state:  [8.06225775 4.58803399]
# opt_nstate:  [8.         4.71238898]
# [-5.030089] [-4.9925528] [0.03753614] 0.1
#
# opt_state:  [7.07106781 4.57049193]
# opt_nstate:  [7.         4.71238898]
# [-4.41615] [-4.3733025] [0.04284763] 0.1
#
# opt_state:  [6.08276253 4.5472403 ]
# opt_nstate:  [6.         4.71238898]
# [-3.8039522] [-3.7540526] [0.04989958] 0.1
#
# opt_state:  [5.09901951 4.51499342]
# opt_nstate:  [5.         4.71238898]
# [-3.1945052] [-3.1348014] [0.05970383] 0.1
#
# opt_state:  [4.12310563 4.46741032]
# opt_nstate:  [4.         4.71238898]
# [-2.5897803] [-2.5155516] [0.07422876] 0.1
#
# opt_state:  [3.16227766 4.39063843]
# opt_nstate:  [3.         4.71238898]
# [-1.9941595] [-1.896301] [0.09785843] 0.1
#
# opt_state:  [4.12310563 1.81577499]
# opt_nstate:  [4.         1.57079633]
# [-2.5680883] [-2.4898515] [0.07823682] 0.1
#
# opt_state:  [5.09901951 1.76819189]
# opt_nstate:  [5.         1.57079633]
# [-3.1720343] [-3.1091013] [0.06293297] 0.1
#
# opt_state:  [6.08276253 1.735945  ]
# opt_nstate:  [6.         1.57079633]
# [-3.780954] [-3.7283518] [0.05260205] 0.1
#
# opt_state:  [7.07106781 1.71269338]
# opt_nstate:  [7.         1.57079633]
# [-4.392772] [-4.347603] [0.04516935] 0.1
#
# opt_state:  [8.06225775 1.69515132]
# opt_nstate:  [8.         1.57079633]
# [-5.006423] [-4.966852] [0.03957081] 0.1
#
# opt_state:  [9.05538514 1.68145355]
# opt_nstate:  [9.         1.57079633]
# [-5.621306] [-5.5861034] [0.0352025] 0.1
#
# opt_state:  [9.05538514 4.8230462 ]
# opt_nstate:  [9.         4.71238898]
# [-5.647006] [-5.6118035] [0.0352025] 0.1
#
# opt_state:  [8.06225775 4.83674397]
# opt_nstate:  [8.         4.71238898]
# [-5.0321226] [-4.9925528] [0.03956985] 0.1
#
# opt_state:  [7.07106781 4.85428603]
# opt_nstate:  [7.         4.71238898]
# [-4.4184723] [-4.3733025] [0.04516983] 0.1
#
# opt_state:  [6.08276253 4.87753766]
# opt_nstate:  [6.         4.71238898]
# [-3.806654] [-3.7540526] [0.05260134] 0.1
#
# opt_state:  [5.09901951 4.90978454]
# opt_nstate:  [5.         4.71238898]
# [-3.1977348] [-3.1348014] [0.06293344] 0.1
#
# opt_state:  [4.12310563 4.95736764]
# opt_nstate:  [4.         4.71238898]
# [-2.593789] [-2.5155516] [0.07823753] 0.1
#
# opt_state:  [3.16227766 1.24904577]
# opt_nstate:  [3.         1.57079633]
# [-1.9684594] [-1.8706009] [0.09785843] 0.1
#
# opt_state:  [4.12310563 1.32581766]
# opt_nstate:  [4.         1.57079633]
# [-2.5640802] [-2.4898515] [0.07422876] 0.1
#
# opt_state:  [5.09901951 1.37340077]
# opt_nstate:  [5.         1.57079633]
# [-3.1688044] [-3.1091013] [0.05970311] 0.1
#
# opt_state:  [6.08276253 1.40564765]
# opt_nstate:  [6.         1.57079633]
# [-3.778252] [-3.7283518] [0.04990005] 0.1
#
# opt_state:  [7.07106781 1.42889927]
# opt_nstate:  [7.         1.57079633]
# [-4.39045] [-4.347603] [0.04284716] 0.1
#
# opt_state:  [8.06225775 1.44644133]
# opt_nstate:  [8.         1.57079633]
# [-5.004389] [-4.966852] [0.03753662] 0.1
#
# opt_state:  [9.05538514 1.46013911]
# opt_nstate:  [9.         1.57079633]
# [-5.6194944] [-5.5861034] [0.033391] 0.1
#
# opt_state:  [4.12310563 0.24497866]
# opt_nstate:  [4. 0.]
# [-2.5552387] [-2.4770012] [0.07823753] 0.1
#
# opt_state:  [5.38516481 5.90267893]
# opt_nstate:  [5.83095189 5.74276581]
# [-3.383052] [-3.6577973] [-0.27474523] 0.1
#
# opt_state:  [6.08276253 0.16514868]
# opt_nstate:  [6. 0.]
# [-3.7681046] [-3.7155018] [0.05260277] 0.1
#
# opt_state:  [7.07106781 6.14128825]
# opt_nstate:  [7. 0.]
# [-4.4290004] [-4.334752] [0.09424829] 0.1
#
# opt_state:  [7.07106781 0.14189705]
# opt_nstate:  [8.06225775 0.12435499]
# [-4.379922] [-4.993573] [-0.6136513] 0.1
#
# opt_state:  [8.06225775 6.15883031]
# opt_nstate:  [8.24621125 6.03820664]
# [-5.042939] [-5.1558647] [-0.11292553] 0.1
#
# opt_state:  [8. 0.]
# opt_nstate:  [8.06225775 6.15883031]
# [-4.9540024] [-5.042939] [-0.08893681] 0.1
#
# opt_state:  [8. 0.]
# opt_nstate:  [8.06225775 0.12435499]
# [-4.9540024] [-4.993573] [-0.03957081] 0.1
#
# opt_state:  [8.06225775 0.12435499]
# opt_nstate:  [8.24621125 0.24497866]
# [-4.993573] [-5.1084733] [-0.11490011] 0.1
#
# opt_state:  [9.05538514 6.17252809]
# opt_nstate:  [9.21954446 6.06451636]
# [-5.658046] [-5.7588177] [-0.1007719] 0.1
#
# opt_state:  [9. 0.]
# opt_nstate:  [9.05538514 6.17252809]
# [-5.573253] [-5.658046] [-0.08479261] 0.1
#
# opt_state:  [9. 0.]
# opt_nstate:  [9.05538514 0.11065722]
# [-5.573253] [-5.6084557] [-0.0352025] 0.1
#
# opt_state:  [9.05538514 0.11065722]
# opt_nstate:  [9.21954446 0.21866895]
# [-5.6084557] [-5.7109947] [-0.10253906] 0.1
# /home/jeff/anaconda3/envs/NCLF/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# /home/jeff/anaconda3/envs/NCLF/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
tf.reduce_mean(tf.nn.relu(margin - (opt_nvals - opt_vals)))
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.011148688>

# %%
num_violations, len(opt_vals)
# Out:
# (54, 491)

# %%
nopt_vals = model.predict(convert_polar_coordinates(np.array(nopt_states)).astype(np.float))
nopt_nvals = model.predict(convert_polar_coordinates(np.array(nopt_nstates)).astype(np.float))

num_violations = 0
for i in range(len(nopt_vals)):
    val, nval = nopt_vals[i], nopt_nvals[i]
    if nval - val > margin:
        print ("nopt_state: ", nopt_states[i])
        print ("nopt_nstate: ", nopt_nstates[i])
        print (val, nval, nval - val, margin)
        print ("")
        num_violations += 1
# Out:
# nopt_state:  (1, 4)
# nopt_nstate:  [1 5]
# [-6.7287273] [-6.4054203] [0.32330704] 0.1
#
# nopt_state:  (1, 6)
# nopt_nstate:  [1 7]
# [-6.12803] [-5.903056] [0.22497368] 0.1
#
# nopt_state:  (1, 7)
# nopt_nstate:  [1 8]
# [-5.903056] [-5.736695] [0.16636133] 0.1
#
# nopt_state:  (1, 8)
# nopt_nstate:  [1 9]
# [-5.736695] [-5.6341558] [0.10253906] 0.1
#
# nopt_state:  (1, 12)
# nopt_nstate:  [ 1 11]
# [-5.7331166] [-5.6323447] [0.1007719] 0.1
#
# nopt_state:  (1, 13)
# nopt_nstate:  [ 1 12]
# [-5.897792] [-5.7331166] [0.16467524] 0.1
#
# nopt_state:  (1, 14)
# nopt_nstate:  [ 1 13]
# [-6.1211877] [-5.897792] [0.22339582] 0.1
#
# nopt_state:  (1, 16)
# nopt_nstate:  [ 1 15]
# [-6.7191067] [-6.3971243] [0.32198238] 0.1
#
# nopt_state:  (2, 3)
# nopt_nstate:  [3 3]
# [-6.6143026] [-6.1623907] [0.45191193] 0.1
#
# nopt_state:  (2, 4)
# nopt_nstate:  [2 5]
# [-6.2234664] [-5.872266] [0.35120058] 0.1
#
# nopt_state:  (2, 5)
# nopt_nstate:  [2 6]
# [-5.872266] [-5.5682364] [0.30402946] 0.1
#
# nopt_state:  (2, 6)
# nopt_nstate:  [2 7]
# [-5.5682364] [-5.319511] [0.24872541] 0.1
#
# nopt_state:  (2, 7)
# nopt_nstate:  [2 8]
# [-5.319511] [-5.1341724] [0.1853385] 0.1
#
# nopt_state:  (2, 8)
# nopt_nstate:  [2 9]
# [-5.1341724] [-5.0192723] [0.11490011] 0.1
#
# nopt_state:  (2, 12)
# nopt_nstate:  [ 2 11]
# [-5.130165] [-5.0172386] [0.11292648] 0.1
#
# nopt_state:  (2, 13)
# nopt_nstate:  [ 2 12]
# [-5.313642] [-5.130165] [0.18347692] 0.1
#
# nopt_state:  (2, 14)
# nopt_nstate:  [ 2 13]
# [-5.560651] [-5.313642] [0.2470088] 0.1
#
# nopt_state:  (2, 15)
# nopt_nstate:  [ 2 14]
# [-5.8631263] [-5.560651] [0.30247545] 0.1
#
# nopt_state:  (2, 16)
# nopt_nstate:  [ 2 15]
# [-6.212939] [-5.8631263] [0.3498125] 0.1
#
# nopt_state:  (2, 17)
# nopt_nstate:  [ 3 17]
# [-6.6025405] [-6.1495404] [0.45300007] 0.1
#
# nopt_state:  (3, 2)
# nopt_nstate:  [3 3]
# [-6.6153903] [-6.1623907] [0.4529996] 0.1
#
# nopt_state:  (3, 4)
# nopt_nstate:  [4 4]
# [-5.7407036] [-5.286638] [0.4540658] 0.1
#
# nopt_state:  (3, 5)
# nopt_nstate:  [3 6]
# [-5.3577666] [-5.0225034] [0.33526325] 0.1
#
# nopt_state:  (3, 7)
# nopt_nstate:  [3 8]
# [-4.745083] [-4.536187] [0.20889568] 0.1
#
# nopt_state:  (3, 8)
# nopt_nstate:  [3 9]
# [-4.536187] [-4.4056225] [0.13056469] 0.1
#
# nopt_state:  (3, 9)
# nopt_nstate:  [4 9]
# [-4.4056225] [-3.793804] [0.61181855] 0.1
#
# nopt_state:  (3, 11)
# nopt_nstate:  [ 4 11]
# [-4.4033003] [-3.7911022] [0.6121981] 0.1
#
# nopt_state:  (3, 12)
# nopt_nstate:  [ 3 11]
# [-4.5316343] [-4.4033003] [0.12833405] 0.1
#
# nopt_state:  (3, 13)
# nopt_nstate:  [ 3 12]
# [-4.7384577] [-4.5316343] [0.20682335] 0.1
#
# nopt_state:  (3, 15)
# nopt_nstate:  [ 3 14]
# [-5.3476186] [-5.0140095] [0.3336091] 0.1
#
# nopt_state:  (3, 16)
# nopt_nstate:  [ 4 16]
# [-5.7291093] [-5.2737875] [0.4553218] 0.1
#
# nopt_state:  (3, 18)
# nopt_nstate:  [ 3 17]
# [-6.6014524] [-6.1495404] [0.45191193] 0.1
#
# nopt_state:  (4, 1)
# nopt_nstate:  [5 1]
# [-6.7319555] [-6.409975] [0.32198048] 0.1
#
# nopt_state:  (4, 2)
# nopt_nstate:  [5 2]
# [-6.2257895] [-5.8759756] [0.34981394] 0.1
#
# nopt_state:  (4, 3)
# nopt_nstate:  [4 4]
# [-5.7419586] [-5.286638] [0.45532084] 0.1
#
# nopt_state:  (4, 5)
# nopt_nstate:  [4 6]
# [-4.8678827] [-4.495988] [0.37189484] 0.1
#
# nopt_state:  (4, 7)
# nopt_nstate:  [4 8]
# [-4.18355] [-3.9448152] [0.23873472] 0.1
#
# nopt_state:  (4, 8)
# nopt_nstate:  [4 9]
# [-3.9448152] [-3.793804] [0.15101123] 0.1
#
# nopt_state:  (4, 12)
# nopt_nstate:  [ 4 11]
# [-3.9395509] [-3.7911022] [0.1484487] 0.1
#
# nopt_state:  (4, 13)
# nopt_nstate:  [ 4 12]
# [-4.175964] [-3.9395509] [0.236413] 0.1
#
# nopt_state:  (4, 15)
# nopt_nstate:  [ 4 14]
# [-4.856516] [-4.486367] [0.37014866] 0.1
#
# nopt_state:  (4, 17)
# nopt_nstate:  [ 4 16]
# [-5.7278533] [-5.2737875] [0.4540658] 0.1
#
# nopt_state:  (4, 18)
# nopt_nstate:  [ 5 18]
# [-6.210617] [-5.8594155] [0.35120153] 0.1
#
# nopt_state:  (4, 19)
# nopt_nstate:  [ 5 19]
# [-6.715877] [-6.392571] [0.32330608] 0.1
#
# nopt_state:  (5, 2)
# nopt_nstate:  [6 2]
# [-5.8759756] [-5.5735] [0.30247545] 0.1
#
# nopt_state:  (5, 3)
# nopt_nstate:  [6 3]
# [-5.360468] [-5.026859] [0.3336091] 0.1
#
# nopt_state:  (5, 4)
# nopt_nstate:  [6 4]
# [-4.869366] [-4.499217] [0.37014914] 0.1
#
# nopt_state:  (5, 6)
# nopt_nstate:  [6 6]
# [-3.9963565] [-3.5351338] [0.46122265] 0.1
#
# nopt_state:  (5, 7)
# nopt_nstate:  [5 8]
# [-3.6409397] [-3.3635778] [0.27736187] 0.1
#
# nopt_state:  (5, 8)
# nopt_nstate:  [5 9]
# [-3.3635778] [-3.1848845] [0.1786933] 0.1
#
# nopt_state:  (5, 9)
# nopt_nstate:  [6 9]
# [-3.1848845] [-2.5809379] [0.6039467] 0.1
#
# nopt_state:  (5, 11)
# nopt_nstate:  [ 6 11]
# [-3.1816545] [-2.5769305] [0.60472393] 0.1
#
# nopt_state:  (5, 12)
# nopt_nstate:  [ 5 11]
# [-3.3573525] [-3.1816545] [0.17569804] 0.1
#
# nopt_state:  (5, 13)
# nopt_nstate:  [ 5 12]
# [-3.6320977] [-3.3573525] [0.27474523] 0.1
#
# nopt_state:  (5, 14)
# nopt_nstate:  [ 6 14]
# [-3.9853172] [-3.5222836] [0.46303368] 0.1
#
# nopt_state:  (5, 15)
# nopt_nstate:  [ 6 15]
# [-4.398036] [-3.9835067] [0.41452932] 0.1
#
# nopt_state:  (5, 16)
# nopt_nstate:  [ 6 16]
# [-4.855034] [-4.4831376] [0.37189627] 0.1
#
# nopt_state:  (5, 17)
# nopt_nstate:  [ 6 17]
# [-5.344917] [-5.0096526] [0.3352642] 0.1
#
# nopt_state:  (5, 18)
# nopt_nstate:  [ 6 18]
# [-5.8594155] [-5.5553865] [0.304029] 0.1
#
# nopt_state:  (5, 19)
# nopt_nstate:  [ 6 19]
# [-6.392571] [-6.1151795] [0.27739143] 0.1
#
# nopt_state:  (6, 1)
# nopt_nstate:  [7 1]
# [-6.1340365] [-5.9106417] [0.22339487] 0.1
#
# nopt_state:  (6, 2)
# nopt_nstate:  [7 2]
# [-5.5735] [-5.3264914] [0.2470088] 0.1
#
# nopt_state:  (6, 3)
# nopt_nstate:  [7 3]
# [-5.026859] [-4.751307] [0.2755518] 0.1
#
# nopt_state:  (6, 5)
# nopt_nstate:  [6 6]
# [-3.998167] [-3.5351338] [0.4630332] 0.1
#
# nopt_state:  (6, 7)
# nopt_nstate:  [7 7]
# [-3.1272159] [-2.6593814] [0.46783447] 0.1
#
# nopt_state:  (6, 8)
# nopt_nstate:  [6 9]
# [-2.7988648] [-2.5809379] [0.21792698] 0.1
#
# nopt_state:  (6, 12)
# nopt_nstate:  [ 6 11]
# [-2.7912786] [-2.5769305] [0.21434808] 0.1
#
# nopt_state:  (6, 13)
# nopt_nstate:  [ 7 13]
# [-3.1166873] [-2.6465313] [0.47015595] 0.1
#
# nopt_state:  (6, 14)
# nopt_nstate:  [ 7 14]
# [-3.5222836] [-3.114366] [0.4079175] 0.1
#
# nopt_state:  (6, 18)
# nopt_nstate:  [ 6 17]
# [-5.5553865] [-5.0096526] [0.5457339] 0.1
#
# nopt_state:  (7, 1)
# nopt_nstate:  [8 1]
# [-5.9106417] [-5.7459674] [0.16467428] 0.1
#
# nopt_state:  (7, 2)
# nopt_nstate:  [8 2]
# [-5.3264914] [-5.1430135] [0.18347788] 0.1
#
# nopt_state:  (7, 3)
# nopt_nstate:  [7 4]
# [-4.751307] [-4.188814] [0.56249285] 0.1
#
# nopt_state:  (7, 4)
# nopt_nstate:  [8 4]
# [-4.188814] [-3.9524007] [0.23641348] 0.1
#
# nopt_state:  (7, 5)
# nopt_nstate:  [8 5]
# [-3.644948] [-3.3702025] [0.27474546] 0.1
#
# nopt_state:  (7, 6)
# nopt_nstate:  [7 7]
# [-3.1295378] [-2.6593814] [0.47015643] 0.1
#
# nopt_state:  (7, 14)
# nopt_nstate:  [ 8 14]
# [-3.114366] [-2.7860143] [0.32835174] 0.1
#
# nopt_state:  (7, 15)
# nopt_nstate:  [ 8 15]
# [-3.6280894] [-3.3507276] [0.27736187] 0.1
#
# nopt_state:  (7, 16)
# nopt_nstate:  [ 8 16]
# [-4.1706996] [-3.9319649] [0.23873472] 0.1
#
# nopt_state:  (7, 17)
# nopt_nstate:  [ 8 17]
# [-4.7322316] [-4.523338] [0.20889378] 0.1
#
# nopt_state:  (7, 18)
# nopt_nstate:  [ 8 18]
# [-5.306662] [-5.1213226] [0.18533945] 0.1
#
# nopt_state:  (7, 19)
# nopt_nstate:  [ 8 19]
# [-5.8902063] [-5.7238445] [0.16636181] 0.1
#
# nopt_state:  (8, 1)
# nopt_nstate:  [9 1]
# [-5.7459674] [-5.645195] [0.10077238] 0.1
#
# nopt_state:  (8, 2)
# nopt_nstate:  [9 2]
# [-5.1430135] [-5.030089] [0.11292458] 0.1
#
# nopt_state:  (8, 3)
# nopt_nstate:  [9 3]
# [-4.544484] [-4.41615] [0.12833405] 0.1
#
# nopt_state:  (8, 4)
# nopt_nstate:  [9 4]
# [-3.9524007] [-3.8039522] [0.14844847] 0.1
#
# nopt_state:  (8, 5)
# nopt_nstate:  [9 5]
# [-3.3702025] [-3.1945052] [0.17569733] 0.1
#
# nopt_state:  (8, 6)
# nopt_nstate:  [9 6]
# [-2.804129] [-2.5897803] [0.21434855] 0.1
#
# nopt_state:  (8, 14)
# nopt_nstate:  [ 8 13]
# [-2.7860143] [-2.250399] [0.5356152] 0.1
#
# nopt_state:  (8, 15)
# nopt_nstate:  [ 8 14]
# [-3.3507276] [-2.7860143] [0.56471324] 0.1
#
# nopt_state:  (8, 15)
# nopt_nstate:  [ 9 15]
# [-3.3507276] [-3.1720343] [0.1786933] 0.1
#
# nopt_state:  (8, 16)
# nopt_nstate:  [ 8 15]
# [-3.9319649] [-3.3507276] [0.5812373] 0.1
#
# nopt_state:  (8, 18)
# nopt_nstate:  [ 9 18]
# [-5.1213226] [-5.006423] [0.11489964] 0.1
#
# nopt_state:  (8, 19)
# nopt_nstate:  [ 9 19]
# [-5.7238445] [-5.621306] [0.10253859] 0.1
#
# nopt_state:  (9, 3)
# nopt_nstate:  [9 4]
# [-4.41615] [-3.8039522] [0.6121979] 0.1
#
# nopt_state:  (9, 4)
# nopt_nstate:  [9 5]
# [-3.8039522] [-3.1945052] [0.609447] 0.1
#
# nopt_state:  (9, 5)
# nopt_nstate:  [9 6]
# [-3.1945052] [-2.5897803] [0.6047249] 0.1
#
# nopt_state:  (9, 15)
# nopt_nstate:  [ 9 14]
# [-3.1720343] [-2.5680883] [0.603946] 0.1
#
# nopt_state:  (9, 17)
# nopt_nstate:  [ 9 16]
# [-4.392772] [-3.780954] [0.6118183] 0.1
#
# nopt_state:  (11, 3)
# nopt_nstate:  [11  4]
# [-4.4184723] [-3.806654] [0.6118183] 0.1
#
# nopt_state:  (11, 5)
# nopt_nstate:  [11  6]
# [-3.1977348] [-2.593789] [0.60394573] 0.1
#
# nopt_state:  (11, 15)
# nopt_nstate:  [11 14]
# [-3.1688044] [-2.5640802] [0.60472417] 0.1
#
# nopt_state:  (11, 17)
# nopt_nstate:  [11 16]
# [-4.39045] [-3.778252] [0.6121981] 0.1
#
# nopt_state:  (12, 1)
# nopt_nstate:  [11  1]
# [-5.749544] [-5.647006] [0.10253811] 0.1
#
# nopt_state:  (12, 2)
# nopt_nstate:  [11  2]
# [-5.1470227] [-5.0321226] [0.11490011] 0.1
#
# nopt_state:  (12, 3)
# nopt_nstate:  [11  3]
# [-4.5490365] [-4.4184723] [0.13056421] 0.1
#
# nopt_state:  (12, 4)
# nopt_nstate:  [11  4]
# [-3.957665] [-3.806654] [0.15101099] 0.1
#
# nopt_state:  (12, 5)
# nopt_nstate:  [11  5]
# [-3.3764277] [-3.1977348] [0.17869282] 0.1
#
# nopt_state:  (12, 6)
# nopt_nstate:  [11  6]
# [-2.8117144] [-2.593789] [0.21792531] 0.1
#
# nopt_state:  (12, 14)
# nopt_nstate:  [11 14]
# [-2.778429] [-2.5640802] [0.2143488] 0.1
#
# nopt_state:  (12, 15)
# nopt_nstate:  [11 15]
# [-3.344502] [-3.1688044] [0.17569757] 0.1
#
# nopt_state:  (12, 16)
# nopt_nstate:  [11 16]
# [-3.926701] [-3.778252] [0.14844918] 0.1
#
# nopt_state:  (12, 17)
# nopt_nstate:  [11 17]
# [-4.5187836] [-4.39045] [0.12833357] 0.1
#
# nopt_state:  (12, 18)
# nopt_nstate:  [12 17]
# [-5.1173153] [-4.5187836] [0.5985317] 0.1
#
# nopt_state:  (12, 19)
# nopt_nstate:  [12 18]
# [-5.720267] [-5.1173153] [0.6029515] 0.1
#
# nopt_state:  (13, 1)
# nopt_nstate:  [12  1]
# [-5.9159064] [-5.749544] [0.16636229] 0.1
#
# nopt_state:  (13, 2)
# nopt_nstate:  [12  2]
# [-5.332361] [-5.1470227] [0.1853385] 0.1
#
# nopt_state:  (13, 3)
# nopt_nstate:  [12  3]
# [-4.7579317] [-4.5490365] [0.2088952] 0.1
#
# nopt_state:  (13, 4)
# nopt_nstate:  [12  4]
# [-4.1964006] [-3.957665] [0.23873568] 0.1
#
# nopt_state:  (13, 5)
# nopt_nstate:  [12  5]
# [-3.6537895] [-3.3764277] [0.27736187] 0.1
#
# nopt_state:  (13, 6)
# nopt_nstate:  [13  7]
# [-3.1400657] [-2.6722312] [0.46783447] 0.1
#
# nopt_state:  (13, 14)
# nopt_nstate:  [13 13]
# [-3.1038375] [-2.6336818] [0.47015572] 0.1
#
# nopt_state:  (13, 15)
# nopt_nstate:  [12 15]
# [-3.6192484] [-3.344502] [0.27474642] 0.1
#
# nopt_state:  (13, 16)
# nopt_nstate:  [12 16]
# [-4.1631145] [-3.926701] [0.23641348] 0.1
#
# nopt_state:  (13, 17)
# nopt_nstate:  [12 17]
# [-4.725608] [-4.5187836] [0.2068243] 0.1
#
# nopt_state:  (13, 18)
# nopt_nstate:  [12 18]
# [-5.300792] [-5.1173153] [0.18347692] 0.1
#
# nopt_state:  (13, 19)
# nopt_nstate:  [12 19]
# [-5.884943] [-5.720267] [0.16467619] 0.1
#
# nopt_state:  (14, 1)
# nopt_nstate:  [13  1]
# [-6.1408796] [-5.9159064] [0.2249732] 0.1
#
# nopt_state:  (14, 2)
# nopt_nstate:  [13  2]
# [-5.581086] [-5.332361] [0.24872494] 0.1
#
# nopt_state:  (14, 5)
# nopt_nstate:  [14  6]
# [-4.0092063] [-3.5479834] [0.4612229] 0.1
#
# nopt_state:  (14, 7)
# nopt_nstate:  [13  7]
# [-3.1423876] [-2.6722312] [0.47015643] 0.1
#
# nopt_state:  (14, 8)
# nopt_nstate:  [14  9]
# [-2.8169794] [-2.6026301] [0.21434927] 0.1
#
# nopt_state:  (14, 12)
# nopt_nstate:  [14 11]
# [-2.7731647] [-2.5552387] [0.21792603] 0.1
#
# nopt_state:  (14, 13)
# nopt_nstate:  [13 13]
# [-3.1015158] [-2.6336818] [0.467834] 0.1
#
# nopt_state:  (14, 15)
# nopt_nstate:  [14 14]
# [-3.9724667] [-3.5094335] [0.4630332] 0.1
#
# nopt_state:  (14, 18)
# nopt_nstate:  [13 18]
# [-5.5478005] [-5.300792] [0.24700832] 0.1
#
# nopt_state:  (14, 19)
# nopt_nstate:  [13 19]
# [-6.1083364] [-5.884943] [0.22339344] 0.1
#
# nopt_state:  (15, 2)
# nopt_nstate:  [14  2]
# [-5.885115] [-5.581086] [0.304029] 0.1
#
# nopt_state:  (15, 3)
# nopt_nstate:  [14  3]
# [-5.370618] [-5.035352] [0.33526564] 0.1
#
# nopt_state:  (15, 4)
# nopt_nstate:  [14  4]
# [-4.8807325] [-4.5088387] [0.37189388] 0.1
#
# nopt_state:  (15, 6)
# nopt_nstate:  [14  6]
# [-4.011017] [-3.5479834] [0.46303344] 0.1
#
# nopt_state:  (15, 7)
# nopt_nstate:  [15  8]
# [-3.6577973] [-3.383052] [0.27474523] 0.1
#
# nopt_state:  (15, 8)
# nopt_nstate:  [14  8]
# [-3.383052] [-2.8169794] [0.5660727] 0.1
#
# nopt_state:  (15, 8)
# nopt_nstate:  [15  9]
# [-3.383052] [-3.207354] [0.17569804] 0.1
#
# nopt_state:  (15, 9)
# nopt_nstate:  [14  9]
# [-3.207354] [-2.6026301] [0.60472393] 0.1
#
# nopt_state:  (15, 12)
# nopt_nstate:  [15 11]
# [-3.337878] [-3.1591845] [0.17869353] 0.1
#
# nopt_state:  (15, 13)
# nopt_nstate:  [15 12]
# [-3.6152396] [-3.337878] [0.27736163] 0.1
#
# nopt_state:  (15, 14)
# nopt_nstate:  [14 14]
# [-3.9706569] [-3.5094335] [0.46122336] 0.1
#
# nopt_state:  (15, 16)
# nopt_nstate:  [14 16]
# [-4.8436666] [-4.4735165] [0.3701501] 0.1
#
# nopt_state:  (15, 17)
# nopt_nstate:  [14 17]
# [-5.334769] [-5.0011587] [0.33361006] 0.1
#
# nopt_state:  (15, 18)
# nopt_nstate:  [14 18]
# [-5.850276] [-5.5478005] [0.30247545] 0.1
#
# nopt_state:  (16, 1)
# nopt_nstate:  [15  1]
# [-6.7415757] [-6.4182706] [0.32330513] 0.1
#
# nopt_state:  (16, 2)
# nopt_nstate:  [15  2]
# [-6.2363176] [-5.885115] [0.3512025] 0.1
#
# nopt_state:  (16, 3)
# nopt_nstate:  [16  4]
# [-5.7535524] [-5.299488] [0.45406437] 0.1
#
# nopt_state:  (16, 5)
# nopt_nstate:  [16  6]
# [-4.882216] [-4.512067] [0.37014914] 0.1
#
# nopt_state:  (16, 7)
# nopt_nstate:  [16  8]
# [-4.2016644] [-3.9652503] [0.2364142] 0.1
#
# nopt_state:  (16, 8)
# nopt_nstate:  [15  8]
# [-3.9652503] [-3.383052] [0.58219814] 0.1
#
# nopt_state:  (16, 11)
# nopt_nstate:  [15 11]
# [-3.7681046] [-3.1591845] [0.6089201] 0.1
#
# nopt_state:  (16, 12)
# nopt_nstate:  [16 11]
# [-3.919115] [-3.7681046] [0.15101051] 0.1
#
# nopt_state:  (16, 13)
# nopt_nstate:  [16 12]
# [-4.1578503] [-3.919115] [0.2387352] 0.1
#
# nopt_state:  (16, 15)
# nopt_nstate:  [16 14]
# [-4.842183] [-4.470288] [0.3718953] 0.1
#
# nopt_state:  (16, 17)
# nopt_nstate:  [16 16]
# [-5.7162595] [-5.2609386] [0.45532084] 0.1
#
# nopt_state:  (16, 18)
# nopt_nstate:  [15 18]
# [-6.200089] [-5.850276] [0.34981298] 0.1
#
# nopt_state:  (16, 19)
# nopt_nstate:  [15 19]
# [-6.7062573] [-6.384274] [0.32198334] 0.1
#
# nopt_state:  (17, 2)
# nopt_nstate:  [17  3]
# [-6.627152] [-6.1752405] [0.45191145] 0.1
#
# nopt_state:  (17, 4)
# nopt_nstate:  [16  4]
# [-5.754809] [-5.299488] [0.45532084] 0.1
#
# nopt_state:  (17, 5)
# nopt_nstate:  [17  6]
# [-5.373318] [-5.0397096] [0.33360863] 0.1
#
# nopt_state:  (17, 7)
# nopt_nstate:  [17  8]
# [-4.764157] [-4.557334] [0.20682287] 0.1
#
# nopt_state:  (17, 9)
# nopt_nstate:  [16  9]
# [-4.4290004] [-3.816801] [0.6121993] 0.1
#
# nopt_state:  (17, 11)
# nopt_nstate:  [16 11]
# [-4.379922] [-3.7681046] [0.61181736] 0.1
#
# nopt_state:  (17, 12)
# nopt_nstate:  [17 11]
# [-4.5104876] [-4.379922] [0.13056564] 0.1
#
# nopt_state:  (17, 13)
# nopt_nstate:  [17 12]
# [-4.719382] [-4.5104876] [0.20889425] 0.1
#
# nopt_state:  (17, 15)
# nopt_nstate:  [17 14]
# [-5.3320675] [-4.996803] [0.33526468] 0.1
#
# nopt_state:  (17, 16)
# nopt_nstate:  [16 16]
# [-5.715003] [-5.2609386] [0.45406437] 0.1
#
# nopt_state:  (17, 18)
# nopt_nstate:  [17 17]
# [-6.5896907] [-6.136691] [0.4529996] 0.1
#
# nopt_state:  (18, 3)
# nopt_nstate:  [17  3]
# [-6.6282415] [-6.1752405] [0.45300102] 0.1
#
# nopt_state:  (18, 4)
# nopt_nstate:  [18  5]
# [-6.238639] [-5.8888254] [0.34981346] 0.1
#
# nopt_state:  (18, 5)
# nopt_nstate:  [18  6]
# [-5.8888254] [-5.5863514] [0.30247402] 0.1
#
# nopt_state:  (18, 6)
# nopt_nstate:  [18  7]
# [-5.5863514] [-5.3393426] [0.2470088] 0.1
#
# nopt_state:  (18, 7)
# nopt_nstate:  [18  8]
# [-5.3393426] [-5.1558647] [0.18347788] 0.1
#
# nopt_state:  (18, 8)
# nopt_nstate:  [18  9]
# [-5.1558647] [-5.042939] [0.11292553] 0.1
#
# nopt_state:  (18, 9)
# nopt_nstate:  [17  9]
# [-5.042939] [-4.4290004] [0.6139388] 0.1
#
# nopt_state:  (18, 10)
# nopt_nstate:  [17 10]
# [-4.9540024] [-4.334752] [0.6192503] 0.1
#
# nopt_state:  (18, 11)
# nopt_nstate:  [17 11]
# [-4.993573] [-4.379922] [0.6136513] 0.1
#
# nopt_state:  (18, 12)
# nopt_nstate:  [18 11]
# [-5.1084733] [-4.993573] [0.11490011] 0.1
#
# nopt_state:  (18, 13)
# nopt_nstate:  [18 12]
# [-5.293812] [-5.1084733] [0.1853385] 0.1
#
# nopt_state:  (18, 14)
# nopt_nstate:  [18 13]
# [-5.5425367] [-5.293812] [0.24872494] 0.1
#
# nopt_state:  (18, 15)
# nopt_nstate:  [18 14]
# [-5.8465652] [-5.5425367] [0.3040285] 0.1
#
# nopt_state:  (18, 16)
# nopt_nstate:  [18 15]
# [-6.1977673] [-5.8465652] [0.351202] 0.1
#
# nopt_state:  (18, 17)
# nopt_nstate:  [17 17]
# [-6.5886025] [-6.136691] [0.45191145] 0.1
#
# nopt_state:  (19, 4)
# nopt_nstate:  [19  5]
# [-6.7448072] [-6.422824] [0.32198334] 0.1
#
# nopt_state:  (19, 6)
# nopt_nstate:  [19  7]
# [-6.146888] [-5.923492] [0.22339582] 0.1
#
# nopt_state:  (19, 7)
# nopt_nstate:  [19  8]
# [-5.923492] [-5.7588177] [0.16467428] 0.1
#
# nopt_state:  (19, 8)
# nopt_nstate:  [19  9]
# [-5.7588177] [-5.658046] [0.1007719] 0.1
#
# nopt_state:  (19, 10)
# nopt_nstate:  [18 10]
# [-5.573253] [-4.9540024] [0.6192508] 0.1
#
# nopt_state:  (19, 12)
# nopt_nstate:  [19 11]
# [-5.7109947] [-5.6084557] [0.10253906] 0.1
#
# nopt_state:  (19, 13)
# nopt_nstate:  [19 12]
# [-5.8773565] [-5.7109947] [0.16636181] 0.1
#
# nopt_state:  (19, 14)
# nopt_nstate:  [19 13]
# [-6.1023307] [-5.8773565] [0.22497416] 0.1
#
# nopt_state:  (19, 16)
# nopt_nstate:  [19 15]
# [-6.703027] [-6.379721] [0.3233056] 0.1
# /home/jeff/anaconda3/envs/NCLF/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """Entry point for launching an IPython kernel.
# /home/jeff/anaconda3/envs/NCLF/lib/python3.7/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations

# %%
num_violations, len(nopt_states)
# Out:
# (1091, 8829)

# %%
def get_control_NCLF(x):
    actions_ = copy.deepcopy(actions)
    nxs = x + actions_ 
#     nxs = np.clip(nxs, 1, env_size - 1)
    nvals = model.predict(convert_polar_coordinates(nxs))
#     print (nvals)
    
    good_acs = np.where(nvals == max(nvals))[0]
#     print (good_acs)
    return np.random.choice(good_acs)

# %%
x = np.array([15, 15])
ac_id = get_control_NCLF(x)
ac_id, actions[ac_id]
# Out:
# (1, array([ 0, -1]))

# %%
x = np.array([10, 1])#copy.deepcopy(start)
# print (x)
for _ in range(500):
#     actions_ = copy.deepcopy(actions)
#     nxs = x + actions_ 
#     nxs = np.clip(nxs, 0, env_size - 1)
#     nvals = model.predict(nxs)
    ac_id = get_control_NCLF(x)
    
#     temp = [q[tuple(x), tuple(actions[i])] for i in range(len(actions))]
#     print (temp)
#     ac_id = np.argmax([q[tuple(x), tuple(actions[i])] for i in range(len(actions))])
    action = copy.deepcopy(actions[ac_id]) 
#     print (action)
#     print (x, action)
    x += action
#     x = (x + action).clip(1, env_size - 1) 
    if 0 in x or env_size in x:
        break
#     print (x)
    if x[0] == goal[0] and x[1] == goal[1]:
        break
x
# Out:
# array([10, 10])

# %%
goal
# Out:
# array([25, 25])

# %%
def generate_NCLF_sets_from_model(model, tolerance_threshold = 0.005):

    states = copy.deepcopy(state_space)
    all_states = np.repeat(states, len(actions), axis = 0)
    all_next_states = np.vstack([copy.deepcopy(actions + state).clip(0, env_size - 1) for state in states])
    assert all_states.shape == all_next_states.shape
    all_vals = model.predict(all_next_states)
    vals_per_state = all_vals.reshape([-1, len(actions)])
    indices = np.arange(vals_per_state.shape[0] * (len(actions))).reshape(vals_per_state.shape)
    opt_indices = np.concatenate([indices_[np.where(np.abs(vals_ - max(vals_)) < tolerance_threshold)] for indices_, vals_ in zip(indices, vals_per_state)])
    nopt_indices = np.concatenate([indices_[np.where(np.abs(vals_ - max(vals_)) >= tolerance_threshold)] for indices_, vals_ in zip(indices, vals_per_state)])

    opt_states = copy.deepcopy(all_states[opt_indices])
    opt_nstates = copy.deepcopy(all_next_states[opt_indices])
    nopt_states = copy.deepcopy(all_states[nopt_indices])
    nopt_nstates = copy.deepcopy(all_next_states[nopt_indices])
    
    data = [np.array(opt_states), np.array(opt_nstates), np.array(nopt_states), np.array(nopt_nstates)]
    return data 

data = generate_NCLF_sets_from_model(model) 
_ = [print(d.shape) for d in data]
# Out:
# (4707, 2)
# (4707, 2)
# (7298, 2)
# (7298, 2)

# %%
margin = .5
num_iters = 100
verbose_iter = 50
lr = 1e-4

model = NCLF(2, [64, 64])
model.compile(Adam(lr = lr))

for epoch in range(100):
    data = generate_NCLF_sets_from_model(model) 
    model.fit(data, margin = margin,
          num_iters = num_iters,
          verbose_iter = verbose_iter)
    print ("----------epoch {} finish--------\n".format(epoch))
# Out:
# iter 0: (0.3691751, 0.3691751, 0.0)
# iter 50: (0.0096059125, 0.0096059125, 0.0)
# ----------epoch 0 finish--------
#
# iter 0: (0.0010982308, 0.0, 0.0010982308)
# iter 50: (0.0018060536, 0.0, 0.0018060536)
# ----------epoch 1 finish--------
#
# iter 0: (0.0019431035, 0.0019431035, 0.0)
# iter 50: (0.0027232708, 0.0027232708, 0.0)
# ----------epoch 2 finish--------
#
# iter 0: (0.00093334983, 0.0, 0.00093334983)
# iter 50: (0.0016262105, 0.0, 0.0016262105)
# ----------epoch 3 finish--------
#
# iter 0: (0.002113038, 0.002113038, 0.0)
# iter 50: (0.0028889813, 0.0028889813, 0.0)
# ----------epoch 4 finish--------
#
# iter 0: (0.0007649011, 0.0, 0.0007649011)
# iter 50: (0.00145814, 0.0, 0.00145814)
# ----------epoch 5 finish--------
#
# iter 0: (0.0022759177, 0.0022759177, 0.0)
# iter 50: (0.0030505976, 0.0030505976, 0.0)
# ----------epoch 6 finish--------
#
# iter 0: (0.00063516595, 0.0, 0.00063516595)
# iter 50: (0.0014791221, 0.0, 0.0014791221)
# ----------epoch 7 finish--------
#
# iter 0: (0.0022438958, 0.0022438958, 0.0)
# iter 50: (0.0030169634, 0.0030169634, 0.0)
# ----------epoch 8 finish--------
#
# iter 0: (0.00062885974, 0.0, 0.00062885974)
# iter 50: (0.0015937306, 0.0, 0.0015937306)
# ----------epoch 9 finish--------
#
# iter 0: (0.002125578, 0.002125578, 0.0)
# iter 50: (0.0028971278, 0.0028971278, 0.0)
# ----------epoch 10 finish--------
#
# iter 0: (0.00074439886, 0.0, 0.00074439886)
# iter 50: (0.001436148, 0.0, 0.001436148)
# ----------epoch 11 finish--------
#
# iter 0: (0.0022821296, 0.0022821296, 0.0)
# iter 50: (0.0030524887, 0.0030524887, 0.0)
# ----------epoch 12 finish--------
#
# iter 0: (0.0006349454, 0.0, 0.0006349454)
# iter 50: (0.0013849454, 0.0, 0.0013849454)
# ----------epoch 13 finish--------
#
# iter 0: (0.002291914, 0.002291914, 0.0)
# iter 50: (0.0027553276, 0.0027553276, 0.0)
# ----------epoch 14 finish--------
#
# iter 0: (0.00087783794, 0.0, 0.00087783794)
# iter 50: (0.0015678338, 0.0, 0.0015678338)
# ----------epoch 15 finish--------
#
# iter 0: (0.0021399232, 0.0021399232, 0.0)
# iter 50: (0.0029076578, 0.0029076578, 0.0)
# ----------epoch 16 finish--------
#
# iter 0: (0.0007189054, 0.0, 0.0007189054)
# iter 50: (0.0014080374, 0.0, 0.0014080374)
# ----------epoch 17 finish--------
#
# iter 0: (0.0022939767, 0.0022939767, 0.0)
# iter 50: (0.0027499727, 0.0027499727, 0.0)
# ----------epoch 18 finish--------
#
# iter 0: (0.0009197359, 0.0, 0.0009197359)
# iter 50: (0.0016082533, 0.0, 0.0016082533)
# ----------epoch 19 finish--------
#
# iter 0: (0.0020881917, 0.0020881917, 0.0)
# iter 50: (0.0028533526, 0.0028533526, 0.0)
# ----------epoch 20 finish--------
#
# iter 0: (0.00076252, 0.0, 0.00076252)
# iter 50: (0.0014499383, 0.0, 0.0014499383)
# ----------epoch 21 finish--------
#
# iter 0: (0.002240328, 0.002240328, 0.0)
# iter 50: (0.003003883, 0.003003883, 0.0)
# ----------epoch 22 finish--------
#
# iter 0: (0.0006208348, 0.0, 0.0006208348)
# iter 50: (0.0013395955, 0.0, 0.0013395955)
# ----------epoch 23 finish--------
#
# iter 0: (0.0021830085, 0.0021830085, 0.0)
# iter 50: (0.0029443724, 0.0029443724, 0.0)
# ----------epoch 24 finish--------
#
# iter 0: (0.00066100265, 0.0, 0.00066100265)
# iter 50: (0.0013467103, 0.0, 0.0013467103)
# ----------epoch 25 finish--------
#
# iter 0: (0.0022781438, 0.0022781438, 0.0)
# iter 50: (0.0030176016, 0.0030176016, 0.0)
# ----------epoch 26 finish--------
#
# iter 0: (0.0006712913, 0.0, 0.0006712913)
# iter 50: (0.0013576271, 0.0, 0.0013576271)
# ----------epoch 27 finish--------
#
# iter 0: (0.0022982561, 0.0022982561, 0.0)
# iter 50: (0.0027696232, 0.0027696232, 0.0)
# ----------epoch 28 finish--------
#
# iter 0: (0.0008277969, 0.0, 0.0008277969)
# iter 50: (0.0015112365, 0.0, 0.0015112365)
# ----------epoch 29 finish--------
#
# iter 0: (0.0021571065, 0.0021571065, 0.0)
# iter 50: (0.0029164134, 0.0029164134, 0.0)
# ----------epoch 30 finish--------
#
# iter 0: (0.00067241554, 0.0, 0.00067241554)
# iter 50: (0.0013545762, 0.0, 0.0013545762)
# ----------epoch 31 finish--------
#
# iter 0: (0.0013634881, 0.0013634881, 0.0)
# iter 50: (0.0019344193, 0.0019344193, 0.0)
# ----------epoch 32 finish--------
#
# iter 0: (0.0016496847, 0.0, 0.0016496847)
# iter 50: (0.0023301318, 0.0, 0.0023301318)
# ----------epoch 33 finish--------
#
# iter 0: (0.0013291221, 0.0013291221, 0.0)
# iter 50: (0.0020873244, 0.0020873244, 0.0)
# ----------epoch 34 finish--------
#
# iter 0: (0.0014907112, 0.0, 0.0014907112)
# iter 50: (0.0021701262, 0.0, 0.0021701262)
# ----------epoch 35 finish--------
#
# iter 0: (0.0014839432, 0.0014839432, 0.0)
# iter 50: (0.002241133, 0.002241133, 0.0)
# ----------epoch 36 finish--------
#
# iter 0: (0.0013319186, 0.0, 0.0013319186)
# iter 50: (0.0020104542, 0.0, 0.0020104542)
# ----------epoch 37 finish--------
#
# iter 0: (0.0016382505, 0.0016382505, 0.0)
# iter 50: (0.0023941689, 0.0023941689, 0.0)
# ----------epoch 38 finish--------
#
# iter 0: (0.0011736586, 0.0, 0.0011736586)
# iter 50: (0.001851016, 0.0, 0.001851016)
# ----------epoch 39 finish--------
#
# iter 0: (0.0017928962, 0.0017928962, 0.0)
# iter 50: (0.002548274, 0.002548274, 0.0)
# ----------epoch 40 finish--------
#
# iter 0: (0.0010144113, 0.0, 0.0010144113)
# iter 50: (0.0016908221, 0.0, 0.0016908221)
# ----------epoch 41 finish--------
#
# iter 0: (0.0019481414, 0.0019481414, 0.0)
# iter 50: (0.0027025589, 0.0027025589, 0.0)
# ----------epoch 42 finish--------
#
# iter 0: (0.0008548665, 0.0, 0.0008548665)
# iter 50: (0.0015297307, 0.0, 0.0015297307)
# ----------epoch 43 finish--------
#
# iter 0: (0.0021045236, 0.0021045236, 0.0)
# iter 50: (0.0028583056, 0.0028583056, 0.0)
# ----------epoch 44 finish--------
#
# iter 0: (0.0006938279, 0.0, 0.0006938279)
# iter 50: (0.0013675699, 0.0, 0.0013675699)
# ----------epoch 45 finish--------
#
# iter 0: (0.0022620554, 0.0022620554, 0.0)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-e76834de7240> in <module>
#      11     model.fit(data, margin = margin,
#      12           num_iters = num_iters,
# ---> 13           verbose_iter = verbose_iter)
#      14     print ("----------epoch {} finish--------\n".format(epoch))
#
# ~/Documents/CLFPolicy/CLF.py in fit(self, data, margin, num_iters, verbose_iter)
#      24     def fit(self, data, margin = 0.5, num_iters = 1000, verbose_iter = None):
#      25         for i in range(num_iters):
# ---> 26             loss = self._train_step(data, margin)
#      27             if verbose_iter is not None and i % verbose_iter == 0:
#      28                 print ("iter {}: {}".format(i, loss))
#
# ~/Documents/CLFPolicy/CLF.py in _train_step(self, data, margin)
#      34             opt_nvals = self.model(opt_nstates)
#      35             nopt_vals = self.model(nopt_states)
# ---> 36             nopt_nvals = self.model(nopt_nstates)
#      37
#      38             # opt_nvals - opt_vals > margin
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1081         with autocast_variable.enable_auto_cast_variables(
#    1082             self._compute_dtype_object):
# -> 1083           outputs = call_fn(inputs, *args, **kwargs)
#    1084
#    1085         if self._activity_regularizer:
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/keras/engine/functional.py in call(self, inputs, training, mask)
#     450     """
#     451     return self._run_internal_graph(
# --> 452         inputs, training=training, mask=mask)
#     453
#     454   def compute_output_shape(self, input_shape):
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     587
#     588         args, kwargs = node.map_arguments(tensor_dict)
# --> 589         outputs = node.layer(*args, **kwargs)
#     590
#     591         # Update tensor_dict.
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1081         with autocast_variable.enable_auto_cast_variables(
#    1082             self._compute_dtype_object):
# -> 1083           outputs = call_fn(inputs, *args, **kwargs)
#    1084
#    1085         if self._activity_regularizer:
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/keras/layers/core/dense.py in call(self, inputs)
#     197             self.kernel, ids, weights, combiner='sum')
#     198       else:
# --> 199         outputs = tf.matmul(a=inputs, b=self.kernel)
#     200     # Broadcast kernel to inputs.
#     201     else:
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in op_dispatch_handler(*args, **kwargs)
#    1094       # Fallback dispatch system (dispatch v1):
#    1095       try:
# -> 1096         return dispatch_target(*args, **kwargs)
#    1097       except (TypeError, ValueError):
#    1098         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in matmul(a, b, transpose_a, transpose_b, adjoint_a, adjoint_b, a_is_sparse, b_is_sparse, output_type, name)
#    3699       else:
#    3700         return gen_math_ops.mat_mul(
# -> 3701             a, b, transpose_a=transpose_a, transpose_b=transpose_b, name=name)
#    3702
#    3703
#
# ~/anaconda3/envs/CLFPolicy/lib/python3.7/site-packages/tensorflow/python/ops/gen_math_ops.py in mat_mul(a, b, transpose_a, transpose_b, name)
#    6013       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6014         _ctx, "MatMul", name, a, b, "transpose_a", transpose_a, "transpose_b",
# -> 6015         transpose_b)
#    6016       return _result
#    6017     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:
